# %%
import numpy as np
import pandas as pd
import io
import matplotlib.pyplot as plt
import torch.nn as nn
import torch
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Dataset/BuyComputer.csv')
# print(data)
data.drop(columns=['User ID',],axis=1,inplace=True)
data.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
#Declare label as last column in the source file
Y=data.iloc[:,-1].values
# print("Label:",Y)
#Declaring X as all columns excluding last
X=data.iloc[:,:-1].values
# print("X:",X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y, random_state=24)
print(X_train.shape)
print(X_test.shape)
# Out:
# (300, 2)
# (100, 2)

# %%
# Scaling data
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Variabes to calculate sigmoid function
y_pred = []
len_x = len(X_train[0])
w = []
b = 0.2
print(len_x)
entries = len(X_train[:,0])
for weights in range(len_x):
    w.append(0)
w
# Out:
# 2
# [0, 0]

# %%
# Sigmoid function
def sigmoid(z):
    return 1/(1 + np.exp(-z))

#Loss function
def loss_func(y, a):
    total_bce_loss = np.sum(-a * np.log(y) - (1 - a) * np.log(1 - y))
    m = y.shape[0]
    j = total_bce_loss /m
    return j
  
#Loss function
def loss_func(y, a):
    total_bce_loss = np.sum(-a * np.log(y) - (1 - a) * np.log(1 - y))
    m = y.shape[0]
    j = total_bce_loss /m
    return j
dw = []
db = 0
J = 0
alpha = 0.1
for x in range(len_x):
    dw.append(0)
def predict(input):
    z = np.dot(input, w) + b
    h= sigmoid(z)
    for i in range(len(h)):
        if(h[i]>=0.5):
            h[i]=1
        else:
            h[i]=0
    return h
#Repeating the process 3000 times
for i in range(3000):
    z = np.dot(X_train, w) + b
    y_pred = sigmoid(z)
    l = loss_func(y_pred, y_train)
    dw = np.dot((y_pred-y_train).T, X_train)/X_train.shape[0]
    db = np.mean(y_pred-y_train)
    w = w - alpha * dw
    b = b - alpha* db
    print("Round:",i,"Weight:",w,"Bias:",b)

y_pred=predict(X_train)
print(y_pred)

# %%
acc = np.sum([y_test[i] == int(y_pred[i]) for i in range(len(y_test))])/len(y_test)
print("Accuracy:",acc)
# Out:
# Accuracy: 0.56

# %%
import numpy as np
import pandas as pd
import io
import matplotlib.pyplot as plt
import torch.nn as nn
import torch
from google.colab import drive
drive.mount("/content/drive")
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Dataset/BuyComputer.csv')
# print(data)
data.drop(columns=['User ID',],axis=1,inplace=True)
data.head()
#Declare label as last column in the source file
Y=data.iloc[:,-1].values
# print("Label:",Y)
#Declaring X as all columns excluding last
X=data.iloc[:,:-1].values
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y, random_state=41)
print(X_train.shape)
print(X_test.shape)
# Fitting Logistic Regression to the Training set
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression(random_state = 41)
from sklearn.metrics import  accuracy_score
#Fit
LR.fit(X_train,y_train)

#predicting the test label with LR. Predict always takes X as input
y_test_hat = LR.predict(X_test)
test_accuracy = accuracy_score(y_test, y_test_hat)*100
print('Testing accuracy', test_accuracy)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# (300, 2)
# (100, 2)
# Testing accuracy 63.0
